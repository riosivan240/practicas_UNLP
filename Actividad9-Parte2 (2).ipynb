# %% [markdown]
# # Actividad 9
# # 🔍 Parte 2: Análisis de Datasets
# Objetivo: Analizar datasets con Pandas, utilizando filtros y visualización con:
# * tablas
# * gráficos
# * mapas

# %% [markdown]
# ## Elegí un dataset
# * Realizar exploración básica

# %% [markdown]
# *  ### Avistajes de felinos en Argentina
#     * Link para descarga: https://archivos.linti.unlp.edu.ar/index.php/s/5iC9FrYWiGi11d0
#     * Nombre del archivo: felinos_filtrado.csv
#     * Descargado y adaptado de: https://www.gbif.org/
#     * Descripción: describe los avistajes de felinos en peligro de extinción con ubicación, especie, fecha etc.
# * ### Áreas protegidas
#     * Link para descarga: https://archivos.linti.unlp.edu.ar/index.php/s/Eqw1eAVC1pdefmb
#     * Descargado de: https://dnsg.ign.gob.ar/apps/api/v1/capas-sig/Geodesia+y+demarcaci%C3%B3n/L%C3%ADmites/area_protegida/csv*
#     * Página consultada: https://www.ign.gob.ar/NuestrasActividades/InformacionGeoespacial/CapasSIG
#     * Descripción: detalle de las áreas protegidas terrestres y marítimas
#     * Documento con detalle de los datos: https://archivos.linti.unlp.edu.ar/index.php/s/9LoXcqzxI8bDzbN
# * ### Aeropuertos Argentina
#     * Link para  descarga: https://archivos.linti.unlp.edu.ar/index.php/s/TYVZ5U6HC457M1k
#     * Nombre del archivo: ar-airports.csv
#     * Descargado de: https://ourairports.com/countries/AR/airports.csv
#     * Descripción: Aeropuertos de Argentina por tipo y localidad
# * ### Conectividad Argentina
#     * Link para descarga: https://archivos.linti.unlp.edu.ar/index.php/s/3k2TO5sSzaAU6IY
#     * Nombre del archivo: Conectividad_Internet.csv
#     * Descargado de : https://datos.gob.ar/dataset/enacom-conectividad-al-servicio-internet/archivo/enacom_CONEC-AL-SERVI-DE-INTER_0
#     * Descripción: Describe las tecnologías disponibles en las localidades para acceder al servicio de Internet fijo y móvil
# * ### Precios combustibles
#     * [Link para descarga](https://archivos.linti.unlp.edu.ar/index.php/s/SaJElA1st0YowO3).
#     * Descargado de: https://www.datos.gob.ar/dataset/energia-precios-surtidor---resolucion-3142016
#     * Descripción: Datos del Sistema en línea de información de precios de combustibles en surtidor, a través del cual los titulares de bocas de expendio de combustibles líquidos inscriptos en el registro creado por la resolución n° 1.102/2004 presentan la información relativa a precios de comercialización minorista dentro de las 8 (ocho) horas de producida una modificación en el precio en surtidor.
# * ### Ferrocarriles.
#     *  [Link para descarga](https://archivos.linti.unlp.edu.ar/index.php/s/Pr6vcKL9fxfmZoj)
#     * Descargado de :https://datos.transporte.gob.ar/dataset/cruces-ferroviarios
#     * Descripción: Cruces ferroviarios con respecto a la red vial nacional. Relevados por la Dirección Nacional de Vialidad. Año 2016.

# %% [markdown]
# # ✅ Etapa 1: Exploración Básica (10 min)
# * Cantidad de filas y columans
# * Nombres de las columnas
# * Tipos de datos de las columnas
# * Ver las primeras 10 filas del dataset

# %%
import pandas as pd 
felinos = pd.read_csv("felinos.csv")
felinos.shape
# Out:
# (2019, 19)

# %%
felinos.columns
# Out:
# Index(['Unnamed: 0', 'kingdom', 'phylum', 'class', 'order', 'family', 'genus',
#        'species', 'locality', 'stateProvince', 'lat', 'lng', 'elevation',
#        'day', 'month', 'year', 'taxonKey', 'ScientificName',
#        'VernacularNames'],
#       dtype='object')

# %%
felinos.dtypes
# Out:
# Unnamed: 0           int64
# kingdom             object
# phylum              object
# class               object
# order               object
# family              object
# genus               object
# species             object
# locality            object
# stateProvince       object
# lat                float64
# lng                float64
# elevation          float64
# day                float64
# month              float64
# year               float64
# taxonKey             int64
# ScientificName      object
# VernacularNames     object
# dtype: object

# %%
felinos.head(10)
# Out:
#    Unnamed: 0   kingdom    phylum     class      order   family genus  \
# 0           0  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 1           1  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 2           2  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 3           3  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 4           4  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 5           5  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 6           6  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 7           7  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 8           8  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
# 9           9  Animalia  Chordata  Mammalia  Carnivora  Felidae  Puma
#
#              species                                         locality  \
# 0  Puma yagouaroundi  <p>Camino acceso al Destacamento Estero Poi</p>
# 1  Puma yagouaroundi             <p>Destacamento de Laguna Blanca</p>
# 2  Puma yagouaroundi                           <p>P.N. El Palmar.</p>
# 3  Puma yagouaroundi                  <p> RP Nº 86, Potrero Nº 15</p>
# 4  Puma yagouaroundi              <p> RP Nº 86, Potrero 2 Grande.</p>
# 5  Puma yagouaroundi                    <p>RP Nº 86, Potrero Nº 1</p>
# 6  Puma yagouaroundi   <p>Borde del Estero Santa Lucía, potrero 5</p>
# 7  Puma yagouaroundi                       <p>Potrero 3, pastizal</p>
# 8  Puma yagouaroundi                       <p>Pastizal potrero 14</p>
# 9  Puma yagouaroundi                      <p>Picada del potrero 6</p>
#
#   stateProvince       lat       lng  elevation   day  month    year  taxonKey  \
# 0       Formosa -25.12069 -58.18679        0.0  19.0    9.0  2006.0   2435146
# 1       Formosa -25.17201 -58.13073        0.0  20.0    9.0  2006.0   2435146
# 2    Entre Ríos -31.88614 -58.30839       24.0   8.0    9.0  2006.0   2435146
# 3    Corrientes -28.04421 -58.12875       69.0  29.0   11.0  2010.0   2435146
# 4    Corrientes -28.01889 -58.05301       74.0  17.0    6.0  2010.0   2435146
# 5    Corrientes -28.03358 -58.09678       69.0  12.0    4.0  2010.0   2435146
# 6    Corrientes -28.01706 -58.00131       72.0  27.0    9.0  2007.0   2435146
# 7    Corrientes -28.03820 -58.11760       70.0  19.0    9.0  2006.0   2435146
# 8    Corrientes -28.04910 -58.12297       68.0   3.0   12.0  2007.0   2435146
# 9    Corrientes -27.99967 -58.01706       71.0  30.0    8.0  2007.0   2435146
#
#       ScientificName                   VernacularNames
# 0  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 1  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 2  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 3  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 4  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 5  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 6  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 7  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 8  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi
# 9  Puma yagouaroundi  Jaguarondi Jaguarundi Yaguarundi

# %% [markdown]
# # ✅ Etapa 2: Análisis por temática(10 min)
# * Cada dataset se analizará según categorías correspondiente a los datos que lo conforman

# %%
felinosp = felinos ["stateProvince"]
felinosp.value_counts()
# Out:
# stateProvince
# Misiones               1253
# Santa Cruz              313
# Corrientes              178
# Formosa                  74
# Neuquén                  66
# Neuquén / Río Negro      44
# Chubut                   24
# Santa Fe                 24
# Entre Ríos               11
# La Pampa                 11
# Chaco                     5
# Córdoba                   3
# Tucumán                   1
# Neuquen                   1
# San Luis                  1
# Jujuy                     1
# Santa cruz                1
# Name: count, dtype: int64

# %%
felinosm = felinos ["genus"]
felinosm.value_counts()
# Out:
# genus
# Puma         1629
# Leopardus     218
# Panthera      172
# Name: count, dtype: int64

# %%
gatito = felinos[felinos["stateProvince"] == "Santa Cruz"]
gatito
# Out:
#       Unnamed: 0   kingdom    phylum     class      order   family      genus  \
# 115          115  Animalia  Chordata  Mammalia  Carnivora  Felidae       Puma
# 116          116  Animalia  Chordata  Mammalia  Carnivora  Felidae       Puma
# 117          117  Animalia  Chordata  Mammalia  Carnivora  Felidae       Puma
# 118          118  Animalia  Chordata  Mammalia  Carnivora  Felidae       Puma
# 119          119  Animalia  Chordata  Mammalia  Carnivora  Felidae       Puma
# ...          ...       ...       ...       ...        ...      ...        ...
# 1880        1880  Animalia  Chordata  Mammalia  Carnivora  Felidae       Puma
# 1881        1881  Animalia  Chordata  Mammalia  Carnivora  Felidae       Puma
# 1882        1882  Animalia  Chordata  Mammalia  Carnivora  Felidae       Puma
# 1926        1926  Animalia  Chordata  Mammalia  Carnivora  Felidae  Leopardus
# 1927        1927  Animalia  Chordata  Mammalia  Carnivora  Felidae  Leopardus
#
#                   species                                           locality  \
# 115         Puma concolor                         <p>Seccional El Rincón</p>
# 116         Puma concolor  <p>Seccional El Rincón, 100 m. en dirección Es...
# 117         Puma concolor  <p>Seccional El Rincón, 100 m. en dirección Es...
# 118         Puma concolor  <p>Muy cercano a las casas de la Seccional El ...
# 119         Puma concolor                          <p>Península Belgrano</p>
# ...                   ...                                                ...
# 1880        Puma concolor  RP 49, 3 km al E de Secc. Bosque Petrificado, ...
# 1881        Puma concolor                  Vegas en Potrero de las Barrancas
# 1882        Puma concolor  Vegas de altura media en Potrero de las Barrancas
# 1926  Leopardus pajonales  <p>Camino a Ea. Las Piedras a 1,5 Km. de la bi...
# 1927  Leopardus pajonales                                                NaN
#
#      stateProvince       lat       lng  elevation   day  month    year  \
# 115     Santa Cruz -47.75305 -72.12120        0.0  28.0    8.0  2010.0
# 116     Santa Cruz -47.75275 -72.11911      918.0  15.0    6.0  2010.0
# 117     Santa Cruz -47.75351 -72.11608      913.0  15.0    7.0  2010.0
# 118     Santa Cruz -47.75450 -72.11712      912.0  29.0    8.0  2010.0
# 119     Santa Cruz -47.83232 -72.09751        0.0  16.0    3.0  2010.0
# ...            ...       ...       ...        ...   ...    ...     ...
# 1880    Santa Cruz -47.68000 -67.99700        0.0   2.0    2.0  2007.0
# 1881    Santa Cruz -47.60015 -68.04985        0.0  26.0    3.0  2001.0
# 1882    Santa Cruz -47.60015 -68.04985        0.0  26.0    3.0  2001.0
# 1926    Santa Cruz -47.62920 -67.90744      105.0  29.0   11.0  2008.0
# 1927    Santa Cruz -47.68992 -68.13180        0.0   5.0    5.0  2006.0
#
#       taxonKey     ScientificName  \
# 115    2435099      Puma concolor
# 116    2435099      Puma concolor
# 117    2435099      Puma concolor
# 118    2435099      Puma concolor
# 119    2435099      Puma concolor
# ...        ...                ...
# 1880   2435099      Puma concolor
# 1881   2435099      Puma concolor
# 1882   2435099      Puma concolor
# 1926  11401493  Leopardus pajeros
# 1927  11401493  Leopardus pajeros
#
#                                         VernacularNames
# 115   Red tiger Puma Cougar León colorado Onza berme...
# 116   Red tiger Puma Cougar León colorado Onza berme...
# 117   Red tiger Puma Cougar León colorado Onza berme...
# 118   Red tiger Puma Cougar León colorado Onza berme...
# 119   Red tiger Puma Cougar León colorado Onza berme...
# ...                                                 ...
# 1880  Red tiger Puma Cougar León colorado Onza berme...
# 1881  Red tiger Puma Cougar León colorado Onza berme...
# 1882  Red tiger Puma Cougar León colorado Onza berme...
# 1926                              Gato de los pajonales
# 1927                              Gato de los pajonales
#
# [313 rows x 19 columns]

# %%
gatito.genus.value_counts()
# Out:
# genus
# Puma         310
# Leopardus      3
# Name: count, dtype: int64

# %% [markdown]
# # ✅ Etapa 3: Filtrar y Limpiar Datos (15 min)

# %% [markdown]
# # ✅ Etapa 4: Valores Nulos y Estadísticas (10 min)
# * Mostrar la composición de las columnas indicando aquellas con datos faltantes

# %% [markdown]
# # ✅ Etapa 5: Visualización con Mapas (15 min)

# %% [markdown]
# *  ### Avistajes de felinos en Argentina
#     * **Mapa**: mostrar iconos de color según el tipo de "genus" .
# * ### Áreas protegidas
#     * **Mapa**: mostrar iconos de color según el tipo de área protegida definida en la columna "tap" que indica (Parque, Reserva, MonumentosNatural).
# * ### Aeropuertos Argentina
#     * **Mapa**: mostrar iconos de color según el tipo de aeropuerto: type
# * ### Conectividad Argentina
#     * **Mapa**: mostrar las localidades donde hay FIBRAOPTICA.
# * ### Precios combustibles
#     *  **Mapa**: mostrar los registros de las provincias de la Patagonia según "tipohorario".
# * ### Ferrocarriles.
#     * **Mapa**: mostrar las estaciones en el mapa según el tipo indicado en la columna "gna".

# %% [markdown]
# ## 📌 Paso 1.Generar un mapa **base** para luego agregar los puntos

# %%
import folium

# %%
def generar_mapa():
    attr = (
        '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> '
        'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</a>'
    )
    
    tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'
    m = folium.Map(
        location=(-33.457606, -65.346857),
        control_scale=True,
        zoom_start=5,
        name='es',
        tiles=tiles,
        attr=attr
    )
    return m

# %%
mapa = generar_mapa()
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6102ad6a27f184a42c70091b22675608 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6102ad6a27f184a42c70091b22675608&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6102ad6a27f184a42c70091b22675608 = L.map(
#                 &quot;map_6102ad6a27f184a42c70091b22675608&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;name&quot;: &quot;es&quot;,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_6102ad6a27f184a42c70091b22675608);
#
#
#
#
#
#             var tile_layer_e737416d099c1d8731fa1e2ec2c5d809 = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e737416d099c1d8731fa1e2ec2c5d809.addTo(map_6102ad6a27f184a42c70091b22675608);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 📌 Paso 2. Definir la función para  agregar los puntos

# %%
def agregar_marca_felinos(row):
    folium.Marker(
        [row['lat'], row['lng']],
        popup=row['genus'],
        icon=folium.Icon()
        ).add_to(mapa)

# %%
felinos.apply(agregar_marca_felinos, axis=1)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6102ad6a27f184a42c70091b22675608 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6102ad6a27f184a42c70091b22675608&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6102ad6a27f184a42c70091b22675608 = L.map(
#                 &quot;map_6102ad6a27f184a42c70091b22675608&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;name&quot;: &quot;es&quot;,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_6102ad6a27f184a42c70091b22675608);
#
#
#
#
#
#             var tile_layer_e737416d099c1d8731fa1e2ec2c5d809 = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e737416d099c1d8731fa1e2ec2c5d809.addTo(map_6102ad6a27f184a42c70091b22675608);
#
#
#             tile_layer_e737416d099c1d8731fa1e2ec2c5d809.addTo(map_6102ad6a27f184a42c70091b22675608);
#
#
#             var marker_d76bd1e003b13b142499f1d203157347 = L.marker(
#                 [-25.12069, -58.18679],
#                 {
# }
#             ).addTo(map_6102ad6a27f184a42c70091b22675608);
#
#
#             var icon_08ebf6a3eaf7a134d1efc8f6b9b04933 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b8e822c76767ebb1a42ffd5522ccb2dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c64435c05a99130afd42d24b2fd9def4 = $(`&lt;div id=&quot;html_c64435c05a99130afd42d24b2fd9def4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Puma&lt;/div&gt;`)[0];
#                 popup_b8e822c76767ebb1a42ffd5522ccb2dd.setContent(html_c64435c05a99130afd42d24b2fd9def4);
#
#
#
#         marker_d76bd1e003b13b142499f1d203157347.bindPopup(popup_b8e822c76767ebb1a42ffd5522ccb2dd)
#         ;
#
#
#
#
#                 marker_d76bd1e003b13b142499f1d203157347.setIcon(icon_08ebf6a3eaf7a134d1efc8f6b9b04933);
#
#
#             var marker_8c112905b2794f751da154a3c92892de = L.marker(
#                 [-25.17201, -58.13073],
#                 {
# }
#             ).addTo(map_6102ad6a27f184a42c70091b22675608);
#
#
#             var icon_a735355af8666ea335f0914a564cf2bc = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_960060c70770a75cab84b536e92f5660 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_307ec84054f9179d665e17e3081faba0 = $(`&lt;div id=&quot;html_307ec84054f9179d665e17e3081faba0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Puma&lt;/div&gt;`)[0];
#                 popup_960060c70770a75cab84b536e92f5660.setContent(html_307ec84054f9179d665e17e3081faba0);
#
#
#
#         marker_8c112905b2794f751da154a3c92892de.bindPopup(popup_960060c70770a75cab84b536e92f5660)
#         ;
#
#
#
#
#                 marker_8c112905b2794f751da154a3c92892de.setIcon(icon_a735355af8666ea335f0914a564cf2bc);
#
#
#             var marker_c451c7edbbb8e2a1d9cb958b86113714 = L.marker(
#                 [-31.88614, -58.30839],
#                 {
# }
#             ).addTo(map_6102ad6a27f184a42c70091b22675608);
#
#
#             var icon_2cb794fee4c28647a89903efc16f8a2e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1f5833635af5f2995b1389eecca45b36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_688079b63a12848e8c053ac29784c465 = $(`&lt;div id=&quot;html_688079b63a12848e8c053ac29784c465&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Puma&lt;/div&gt;`)[0];
#                 popup_1f5833635af5f2995b1389eecca45b36.setContent

# %% [markdown]
# ## 📌 Paso 3. Agrergar los puntos al mapa
